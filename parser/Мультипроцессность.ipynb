# %%
from multiprocess import Pool
from multiprocess import cpu_count

def get_film (url):
    import requests as requests
    from bs4 import BeautifulSoup
    r = requests.get("https://www.kinopoisk.ru" + url.strip())
    html = BeautifulSoup(r.content)
    title = html.find("span", {"class":"moviename-title-wrapper"}).get_text()
    tags = html.find_all("td", {"class": "dollar"})
    budget = ""
    sales_www = ""
    if len(tags) > 0:
        sales_www = tags[0].get_text()
        if len(tags) > 1:
            budget = tags[0].get_text()
            sales_www = tags[1].get_text()
            if len(tags) > 2:
                sales_www = tags[2].get_text()
    return [url, title, budget, sales_www]

pool = Pool(cpu_count() * 2)
data = []
with open("films.txt", "r") as f:
    result_iter = pool.map(get_film, f)
    for result in result_iter:
        data.append(result)
print (data)
# Out:
# [['/film/326/\n', 'Побег из Шоушенка', '\n$25\xa0000\xa0000 ', '\n\n+\xa0$31\xa0500\xa0000\xa0=\xa0$59\xa0841\xa0469 сборы \n var is_world_box_popup = false; \n'], ['/film/435/\n', 'Зеленая миля', '\n$60\xa0000\xa0000 ', '\n\n$136\xa0801\xa0374  \n var is_usa_box_popup = true; \n'], ['/film/448/\n', 'Форрест Гамп', '\n$55\xa0000\xa0000 ', '\n\n+\xa0$347\xa0692\xa0187\xa0=\xa0$677\xa0386\xa0686 сборы \n var is_world_box_popup = false; \n'], ['/film/329/\n', 'Список Шиндлера', '\n$22\xa0000\xa0000 ', '\n\n+\xa0$225\xa0200\xa0000\xa0=\xa0$321\xa0265\xa0768 сборы \n var is_world_box_popup = false; \n'], ['/film/535341/\n', '1+1', '\n\n$10\xa0198\xa0820  \n var is_usa_box_popup = true; \n', '\n\n$1\xa0725\xa0813  \n var is_rus_box_popup = true; \n'], ['/film/447301/\n', 'Начало', '\n$160\xa0000\xa0000 ', '\n\n+\xa0$532\xa0956\xa0569\xa0=\xa0$825\xa0532\xa0764  сборы \n var is_world_box_popup = true; \n'], ['/film/389/\n', 'Леон', '\nFRF 115\xa0000\xa0000 ', '\n\n$19\xa0501\xa0238  сборы \n var is_usa_box_popup = true; \n'], ['/film/2360/\n', 'Король Лев', '\n$45\xa0000\xa0000 ', '\n\n+\xa0$564\xa0700\xa0000\xa0=\xa0$987\xa0483\xa0777  сборы \n var is_world_box_popup = true; \n'], ['/film/361/\n', 'Бойцовский клуб', '\n$63\xa0000\xa0000 ', '\n\n+\xa0$63\xa0823\xa0651\xa0=\xa0$100\xa0853\xa0753 сборы \n var is_world_box_popup = false; \n'], ['/film/42664/\n', 'Иван Васильевич меняет профессию', '', ''], ['/film/381/\n', 'Жизнь прекрасна', '\n$20\xa0000\xa0000 ', '\n\n+\xa0$171\xa0600\xa0000\xa0=\xa0$229\xa0163\xa0264 сборы \n var is_world_box_popup = false; \n'], ['/film/32898/\n', 'Достучаться до небес', '\nDEM 4\xa0300\xa0000 ', '\n\n$5\xa0710  сборы \n var is_usa_box_popup = true; \n'], ['/film/325/\n', 'Крестный отец', '\n$6\xa0000\xa0000 ', '\n\n+\xa0$110\xa0100\xa0000\xa0=\xa0$245\xa0066\xa0411 сборы \n var is_world_box_popup = false; \n'], ['/film/342/\n', 'Криминальное чтиво', '\n$8\xa0000\xa0000 ', '\n\n+\xa0$106\xa0000\xa0000\xa0=\xa0$213\xa0928\xa0762 сборы \n var is_world_box_popup = false; \n'], ['/film/42782/\n', 'Операция «Ы» и другие приключения Шурика', '', ''], ['/film/195334/\n', 'Престиж', '\n$40\xa0000\xa0000 ', '\n\n+\xa0$56\xa0586\xa0420\xa0=\xa0$109\xa0676\xa0311  сборы \n var is_world_box_popup = true; \n'], ['/film/530/\n', 'Игры разума', '\n$58\xa0000\xa0000 ', '\n\n$170\xa0742\xa0341  \n var is_usa_box_popup = true; \n'], ['/film/258687/\n', 'Интерстеллар', '\n$165\xa0000\xa0000 ', '\n\n+\xa0$487\xa0100\xa0000\xa0=\xa0$675\xa0120\xa0017  сборы \n var is_world_box_popup = true; \n'], ['/film/474/\n', 'Гладиатор', '\n$103\xa0000\xa0000 ', '\n\n$187\xa0705\xa0427  \n var is_usa_box_popup = true; \n'], ['/film/3498/\n', 'Властелин колец: Возвращение Короля', '\n$94\xa0000\xa0000 ', '\n\n$377\xa0027\xa0325  \n var is_usa_box_popup = true; \n'], ['/film/476/\n', 'Назад в будущее', '\n$19\xa0000\xa0000 ', '\n\n+\xa0$170\xa0500\xa0000\xa0=\xa0$381\xa0109\xa0762 сборы \n var is_world_box_popup = false; \n'], ['/film/522/\n', 'Карты, деньги, два ствола', '', '\n\n$3\xa0753\xa0929  сборы \n var is_usa_box_popup = true; \n'], ['/film/301/\n', 'Матрица', '\n$63\xa0000\xa0000 ', '\n\n$171\xa0479\xa0930  \n var is_usa_box_popup = true; \n'], ['/film/46225/\n', 'Бриллиантовая рука', '', ''], ['/film/81314/\n', 'Отступники', '\n$90\xa0000\xa0000 ', '\n\n+\xa0$157\xa0463\xa0039\xa0=\xa0$289\xa0847\xa0354  сборы \n var is_world_box_popup = true; \n'], ['/film/7660/\n', 'Холодное лето пятьдесят третьего...', '', ''], ['/film/42667/\n', 'Иваново детство', '', ''], ['/film/102124/\n', 'Пираты Карибского моря: На краю Света', '\n$300\xa0000\xa0000 ', '\n\n+\xa0$654\xa0000\xa0000\xa0=\xa0$963\xa0420\xa0425  сборы \n var is_world_box_popup = true; \n'], ['/film/39259/\n', 'Профессионал', '', ''], ['/film/363/\n', 'Секреты Лос-Анджелеса', '\n$35\xa0000\xa0000 ', '\n\n+\xa0$61\xa0600\xa0000\xa0=\xa0$126\xa0216\xa0940 сборы \n var is_world_box_popup = false; \n'], ['/film/843772/\n', 'Фантастические твари и где они обитают\xa03', '', ...
